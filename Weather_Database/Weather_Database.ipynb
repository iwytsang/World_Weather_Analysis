# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | morant bay
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | muros
# Processing Record 7 of Set 1 | faya
# Processing Record 8 of Set 1 | north platte
# Processing Record 9 of Set 1 | huarmey
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | omsukchan
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | kununurra
# Processing Record 19 of Set 1 | manoel urbano
# Processing Record 20 of Set 1 | coahuayana
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | forestville
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | atar
# Processing Record 26 of Set 1 | green river
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | kendari
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | sergiyevsk
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | yekepa
# Processing Record 34 of Set 1 | verkhnevilyuysk
# Processing Record 35 of Set 1 | koulikoro
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | bar harbor
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 1 | muzhi
# Processing Record 46 of Set 1 | goderich
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 1 | macheng
# Processing Record 1 of Set 2 | gushi
# Processing Record 2 of Set 2 | handwara
# City not found. Skipping...
# Processing Record 3 of Set 2 | tautira
# Processing Record 4 of Set 2 | henderson
# Processing Record 5 of Set 2 | kloulklubed
# Processing Record 6 of Set 2 | lubumbashi
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | kahului
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | katsiveli
# City not found. Skipping...
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | waingapu
# Processing Record 16 of Set 2 | de-kastri
# Processing Record 17 of Set 2 | hella
# Processing Record 18 of Set 2 | uyuni
# Processing Record 19 of Set 2 | maicao
# Processing Record 20 of Set 2 | mango
# Processing Record 21 of Set 2 | vestmannaeyjar
# Processing Record 22 of Set 2 | san policarpo
# Processing Record 23 of Set 2 | rakai
# Processing Record 24 of Set 2 | corinto
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 2 | comodoro rivadavia
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | aykhal
# Processing Record 30 of Set 2 | rocha
# Processing Record 31 of Set 2 | fukue
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | biltine
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | avigliana
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | botwood
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | tuatapere
# Processing Record 49 of Set 2 | vostok
# Processing Record 50 of Set 2 | gwadar
# Processing Record 1 of Set 3 | kieta
# Processing Record 2 of Set 3 | kushmurun
# Processing Record 3 of Set 3 | port hardy
# Processing Record 4 of Set 3 | hammerfest
# Processing Record 5 of Set 3 | seda
# Processing Record 6 of Set 3 | goure
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | hervey bay
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | hasaki
# Processing Record 11 of Set 3 | sao lourenco da mata
# Processing Record 12 of Set 3 | velyka pysarivka
# Processing Record 13 of Set 3 | ileza
# Processing Record 14 of Set 3 | cartagena del chaira
# Processing Record 15 of Set 3 | murgab
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | matagami
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | bathsheba
# Processing Record 21 of Set 3 | alta floresta
# Processing Record 22 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 23 of Set 3 | christchurch
# Processing Record 24 of Set 3 | petrozavodsk
# Processing Record 25 of Set 3 | mondeville
# Processing Record 26 of Set 3 | carate brianza
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | iracoubo
# Processing Record 29 of Set 3 | nova granada
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | san ramon de la nueva oran
# Processing Record 32 of Set 3 | alofi
# Processing Record 33 of Set 3 | udachnyy
# Processing Record 34 of Set 3 | ntoum
# Processing Record 35 of Set 3 | preobrazheniye
# Processing Record 36 of Set 3 | el prat de llobregat
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | caldas novas
# Processing Record 40 of Set 3 | xining
# Processing Record 41 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 3 | pontes e lacerda
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | auki
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | hoi an
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | araouane
# Processing Record 1 of Set 4 | selfoss
# Processing Record 2 of Set 4 | haines junction
# Processing Record 3 of Set 4 | dingle
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | dali
# Processing Record 6 of Set 4 | pemangkat
# Processing Record 7 of Set 4 | buchanan
# Processing Record 8 of Set 4 | hobart
# Processing Record 9 of Set 4 | vaitape
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | san pedro del parana
# Processing Record 12 of Set 4 | constitucion
# Processing Record 13 of Set 4 | pacific grove
# Processing Record 14 of Set 4 | sinfra
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | komsomolskiy
# Processing Record 17 of Set 4 | aksu
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | aranos
# Processing Record 20 of Set 4 | busdi
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | khoy
# Processing Record 23 of Set 4 | kumeny
# Processing Record 24 of Set 4 | changji
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | hermanus
# Processing Record 27 of Set 4 | elko
# Processing Record 28 of Set 4 | mareeba
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | padang
# Processing Record 31 of Set 4 | biak
# Processing Record 32 of Set 4 | morondava
# Processing Record 33 of Set 4 | pisco
# Processing Record 34 of Set 4 | lavrentiya
# Processing Record 35 of Set 4 | flinders
# Processing Record 36 of Set 4 | kiruna
# Processing Record 37 of Set 4 | manavalakurichi
# Processing Record 38 of Set 4 | homer
# Processing Record 39 of Set 4 | southampton
# Processing Record 40 of Set 4 | inhambane
# Processing Record 41 of Set 4 | beisfjord
# Processing Record 42 of Set 4 | pokhara
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | ribeira grande
# Processing Record 45 of Set 4 | atuona
# Processing Record 46 of Set 4 | hyeres
# Processing Record 47 of Set 4 | lander
# Processing Record 48 of Set 4 | lukovetskiy
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | sao joao da barra
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | namatanai
# Processing Record 4 of Set 5 | xai-xai
# Processing Record 5 of Set 5 | alta
# Processing Record 6 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 5 | bubaque
# Processing Record 8 of Set 5 | metro
# Processing Record 9 of Set 5 | sungaipenuh
# Processing Record 10 of Set 5 | ahuimanu
# Processing Record 11 of Set 5 | lasa
# Processing Record 12 of Set 5 | chandler
# Processing Record 13 of Set 5 | vanimo
# Processing Record 14 of Set 5 | iskateley
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 5 | segezha
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | ternate
# Processing Record 20 of Set 5 | hargeysa
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | mitu
# Processing Record 23 of Set 5 | manzhouli
# Processing Record 24 of Set 5 | hanna
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | manta
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | nemuro
# Processing Record 30 of Set 5 | dikson
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | dukhovshchina
# Processing Record 33 of Set 5 | zhicheng
# Processing Record 34 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 5 | sinnamary
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | havre-saint-pierre
# Processing Record 39 of Set 5 | zdvinsk
# Processing Record 40 of Set 5 | ulladulla
# Processing Record 41 of Set 5 | port blair
# Processing Record 42 of Set 5 | tecoanapa
# Processing Record 43 of Set 5 | mitsamiouli
# Processing Record 44 of Set 5 | khatanga
# Processing Record 45 of Set 5 | calvinia
# Processing Record 46 of Set 5 | saldanha
# Processing Record 47 of Set 5 | takoradi
# Processing Record 48 of Set 5 | aguimes
# Processing Record 49 of Set 5 | tessalit
# Processing Record 50 of Set 5 | balaipungut
# Processing Record 1 of Set 6 | povenets
# Processing Record 2 of Set 6 | rodrigues alves
# Processing Record 3 of Set 6 | ponnani
# Processing Record 4 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 6 | ugoofaaru
# Processing Record 8 of Set 6 | evensk
# Processing Record 9 of Set 6 | strezhevoy
# Processing Record 10 of Set 6 | the valley
# Processing Record 11 of Set 6 | inverell
# Processing Record 12 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 6 | huilong
# Processing Record 14 of Set 6 | garmsar
# Processing Record 15 of Set 6 | namibe
# Processing Record 16 of Set 6 | vrises
# Processing Record 17 of Set 6 | gao
# Processing Record 18 of Set 6 | puerto carreno
# Processing Record 19 of Set 6 | hastings
# Processing Record 20 of Set 6 | noyabrsk
# Processing Record 21 of Set 6 | muyezerskiy
# Processing Record 22 of Set 6 | shu
# Processing Record 23 of Set 6 | boyuibe
# Processing Record 24 of Set 6 | bengkulu
# Processing Record 25 of Set 6 | hengyang
# Processing Record 26 of Set 6 | minna
# Processing Record 27 of Set 6 | remerschen
# Processing Record 28 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | yenagoa
# Processing Record 31 of Set 6 | price
# Processing Record 32 of Set 6 | singaraja
# Processing Record 33 of Set 6 | praia da vitoria
# Processing Record 34 of Set 6 | faanui
# Processing Record 35 of Set 6 | saint albans
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | merauke
# Processing Record 38 of Set 6 | zhigansk
# Processing Record 39 of Set 6 | puerto del rosario
# Processing Record 40 of Set 6 | astipalaia
# City not found. Skipping...
# Processing Record 41 of Set 6 | faribault
# Processing Record 42 of Set 6 | opuwo
# Processing Record 43 of Set 6 | shumskiy
# Processing Record 44 of Set 6 | chicama
# Processing Record 45 of Set 6 | buraydah
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | thompson
# Processing Record 48 of Set 6 | souillac
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | verkhoyansk
# Processing Record 1 of Set 7 | flin flon
# Processing Record 2 of Set 7 | altay
# Processing Record 3 of Set 7 | port hedland
# Processing Record 4 of Set 7 | muli
# Processing Record 5 of Set 7 | cody
# Processing Record 6 of Set 7 | port-gentil
# Processing Record 7 of Set 7 | talnakh
# Processing Record 8 of Set 7 | gat
# Processing Record 9 of Set 7 | kavaratti
# Processing Record 10 of Set 7 | tokur
# Processing Record 11 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 7 | rongcheng
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | sisimiut
# Processing Record 15 of Set 7 | champasak
# Processing Record 16 of Set 7 | xiashi
# Processing Record 17 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 7 | balkanabat
# Processing Record 19 of Set 7 | mackay
# Processing Record 20 of Set 7 | kangaatsiaq
# Processing Record 21 of Set 7 | jalu
# Processing Record 22 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 7 | rio grande
# Processing Record 24 of Set 7 | beloha
# Processing Record 25 of Set 7 | klaksvik
# Processing Record 26 of Set 7 | gossaigaon
# Processing Record 27 of Set 7 | santa maria
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | bulalacao
# Processing Record 30 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | kiama
# Processing Record 33 of Set 7 | molina
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 36 of Set 7 | anshun
# Processing Record 37 of Set 7 | shieli
# Processing Record 38 of Set 7 | namwala
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | puerto quijarro
# Processing Record 41 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 7 | matehuala
# Processing Record 43 of Set 7 | clovis
# Processing Record 44 of Set 7 | ixtapa
# Processing Record 45 of Set 7 | trairi
# Processing Record 46 of Set 7 | xudat
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | belmonte
# Processing Record 1 of Set 8 | mandalgovi
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | meulaboh
# Processing Record 4 of Set 8 | pula
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | road town
# Processing Record 7 of Set 8 | casma
# Processing Record 8 of Set 8 | touros
# Processing Record 9 of Set 8 | imuris
# Processing Record 10 of Set 8 | baoro
# Processing Record 11 of Set 8 | kimbe
# Processing Record 12 of Set 8 | shar
# Processing Record 13 of Set 8 | jiaocheng
# Processing Record 14 of Set 8 | lata
# Processing Record 15 of Set 8 | baringo
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | sola
# Processing Record 18 of Set 8 | marsa matruh
# Processing Record 19 of Set 8 | adrar
# Processing Record 20 of Set 8 | tank
# Processing Record 21 of Set 8 | vila franca do campo
# Processing Record 22 of Set 8 | tazovskiy
# Processing Record 23 of Set 8 | kysyl-syr
# Processing Record 24 of Set 8 | hambantota
# Processing Record 25 of Set 8 | manadhoo
# Processing Record 26 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 8 | moroto
# Processing Record 28 of Set 8 | lenggries
# Processing Record 29 of Set 8 | gustavo diaz ordaz
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | quatre cocos
# Processing Record 32 of Set 8 | emerald
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | porto novo
# Processing Record 35 of Set 8 | polovinnoye
# Processing Record 36 of Set 8 | victoria
# Processing Record 37 of Set 8 | laguna
# Processing Record 38 of Set 8 | sorland
# Processing Record 39 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | tuensang
# Processing Record 41 of Set 8 | havelock
# Processing Record 42 of Set 8 | beipiao
# Processing Record 43 of Set 8 | ulkan
# Processing Record 44 of Set 8 | kudahuvadhoo
# Processing Record 45 of Set 8 | mindelo
# Processing Record 46 of Set 8 | fernley
# Processing Record 47 of Set 8 | nouadhibou
# Processing Record 48 of Set 8 | marquette
# Processing Record 49 of Set 8 | papasquiaro
# City not found. Skipping...
# Processing Record 50 of Set 8 | dunedin
# Processing Record 1 of Set 9 | kargasok
# Processing Record 2 of Set 9 | hobe sound
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | morros
# Processing Record 5 of Set 9 | airai
# Processing Record 6 of Set 9 | ponta do sol
# Processing Record 7 of Set 9 | koygorodok
# Processing Record 8 of Set 9 | benguela
# Processing Record 9 of Set 9 | chunhuhub
# Processing Record 10 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 9 | domoni
# Processing Record 13 of Set 9 | pochutla
# Processing Record 14 of Set 9 | khandbari
# Processing Record 15 of Set 9 | ginda
# Processing Record 16 of Set 9 | del rio
# Processing Record 17 of Set 9 | dengzhou
# Processing Record 18 of Set 9 | vagur
# Processing Record 19 of Set 9 | valle de allende
# Processing Record 20 of Set 9 | barcelos
# Processing Record 21 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 9 | khandyga
# Processing Record 23 of Set 9 | basco
# Processing Record 24 of Set 9 | castro marim
# Processing Record 25 of Set 9 | san carlos
# Processing Record 26 of Set 9 | damavand
# Processing Record 27 of Set 9 | wladyslawowo
# Processing Record 28 of Set 9 | saint george
# Processing Record 29 of Set 9 | urusha
# Processing Record 30 of Set 9 | asau
# Processing Record 31 of Set 9 | davila
# Processing Record 32 of Set 9 | duldurga
# Processing Record 33 of Set 9 | olafsvik
# Processing Record 34 of Set 9 | luanda
# Processing Record 35 of Set 9 | oreanda
# City not found. Skipping...
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | acapulco
# Processing Record 38 of Set 9 | kajaani
# Processing Record 39 of Set 9 | esmeraldas
# Processing Record 40 of Set 9 | brae
# Processing Record 41 of Set 9 | gold coast
# Processing Record 42 of Set 9 | maniitsoq
# Processing Record 43 of Set 9 | kinkala
# Processing Record 44 of Set 9 | atbasar
# Processing Record 45 of Set 9 | seddon
# Processing Record 46 of Set 9 | ahvaz
# Processing Record 47 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 48 of Set 9 | raudeberg
# Processing Record 49 of Set 9 | xinye
# Processing Record 50 of Set 9 | avera
# Processing Record 1 of Set 10 | coihaique
# Processing Record 2 of Set 10 | oussouye
# Processing Record 3 of Set 10 | ribas do rio pardo
# Processing Record 4 of Set 10 | nizhniy kuranakh
# Processing Record 5 of Set 10 | pafos
# Processing Record 6 of Set 10 | nakamura
# Processing Record 7 of Set 10 | pitimbu
# Processing Record 8 of Set 10 | ponta delgada
# Processing Record 9 of Set 10 | okhotsk
# Processing Record 10 of Set 10 | ardakan
# Processing Record 11 of Set 10 | stephenville
# Processing Record 12 of Set 10 | manakara
# Processing Record 13 of Set 10 | jasper
# Processing Record 14 of Set 10 | borogontsy
# Processing Record 15 of Set 10 | ureki
# Processing Record 16 of Set 10 | pentaplatanon
# Processing Record 17 of Set 10 | joshimath
# Processing Record 18 of Set 10 | kommunar
# Processing Record 19 of Set 10 | nola
# Processing Record 20 of Set 10 | garcia hernandez
# Processing Record 21 of Set 10 | bambous virieux
# Processing Record 22 of Set 10 | houlton
# Processing Record 23 of Set 10 | ust-omchug
# Processing Record 24 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 10 | kazachinskoye
# Processing Record 26 of Set 10 | maningrida
# Processing Record 27 of Set 10 | henties bay
# Processing Record 28 of Set 10 | itacare
# Processing Record 29 of Set 10 | urumqi
# Processing Record 30 of Set 10 | puiesti
# Processing Record 31 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 10 | deputatskiy
# Processing Record 33 of Set 10 | spassk
# Processing Record 34 of Set 10 | barberton
# Processing Record 35 of Set 10 | ojinaga
# Processing Record 36 of Set 10 | marau
# Processing Record 37 of Set 10 | severo-kurilsk
# Processing Record 38 of Set 10 | constantine
# Processing Record 39 of Set 10 | bucovice
# Processing Record 40 of Set 10 | komsomolskoye
# Processing Record 41 of Set 10 | agirish
# Processing Record 42 of Set 10 | sharlyk
# Processing Record 43 of Set 10 | san vicente de canete
# Processing Record 44 of Set 10 | natal
# Processing Record 45 of Set 10 | hofn
# Processing Record 46 of Set 10 | tual
# Processing Record 47 of Set 10 | yaan
# Processing Record 48 of Set 10 | jackson
# Processing Record 49 of Set 10 | scottsbluff
# Processing Record 50 of Set 10 | san cristobal
# Processing Record 1 of Set 11 | vao
# Processing Record 2 of Set 11 | moose factory
# Processing Record 3 of Set 11 | gazojak
# Processing Record 4 of Set 11 | seydi
# Processing Record 5 of Set 11 | codrington
# Processing Record 6 of Set 11 | cobija
# Processing Record 7 of Set 11 | hailar
# Processing Record 8 of Set 11 | fairbanks
# Processing Record 9 of Set 11 | deoria
# Processing Record 10 of Set 11 | dawei
# Processing Record 11 of Set 11 | porosozero
# Processing Record 12 of Set 11 | sabaudia
# Processing Record 13 of Set 11 | teluk nibung
# Processing Record 14 of Set 11 | dolinsk
# Processing Record 15 of Set 11 | nantucket
# Processing Record 16 of Set 11 | buckingham
# Processing Record 17 of Set 11 | amapa
# Processing Record 18 of Set 11 | berlevag
# Processing Record 19 of Set 11 | belaya gora
# Processing Record 20 of Set 11 | tiznit
# Processing Record 21 of Set 11 | tortoli
# Processing Record 22 of Set 11 | port moresby
# Processing Record 23 of Set 11 | wamba
# Processing Record 24 of Set 11 | manhattan
# Processing Record 25 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 11 | grand-lahou
# Processing Record 27 of Set 11 | bardiyah
# Processing Record 28 of Set 11 | alakurtti
# Processing Record 29 of Set 11 | lashio
# Processing Record 30 of Set 11 | rumoi
# Processing Record 31 of Set 11 | nome
# Processing Record 32 of Set 11 | nanortalik
# Processing Record 33 of Set 11 | poquoson
# Processing Record 34 of Set 11 | alanya
# Processing Record 35 of Set 11 | sakakah
# Processing Record 36 of Set 11 | vilyuysk
# Processing Record 37 of Set 11 | dumas
# Processing Record 38 of Set 11 | ngunguru
# Processing Record 39 of Set 11 | ostrovnoy
# Processing Record 40 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 11 | hihya
# Processing Record 42 of Set 11 | murighiol
# Processing Record 43 of Set 11 | dwarka
# Processing Record 44 of Set 11 | san quintin
# Processing Record 45 of Set 11 | dakar
# Processing Record 46 of Set 11 | ukiah
# Processing Record 47 of Set 11 | rawson
# Processing Record 48 of Set 11 | brewster
# Processing Record 49 of Set 11 | eydhafushi
# Processing Record 50 of Set 11 | simav
# Processing Record 1 of Set 12 | jibuti
# Processing Record 2 of Set 12 | noumea
# Processing Record 3 of Set 12 | dolores
# Processing Record 4 of Set 12 | goma
# Processing Record 5 of Set 12 | poum
# Processing Record 6 of Set 12 | sechura
# Processing Record 7 of Set 12 | pekalongan
# Processing Record 8 of Set 12 | nuuk
# Processing Record 9 of Set 12 | port macquarie
# Processing Record 10 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 11 of Set 12 | wajima
# Processing Record 12 of Set 12 | olinda
# Processing Record 13 of Set 12 | katsuura
# Processing Record 14 of Set 12 | iberia
# Processing Record 15 of Set 12 | balad
# Processing Record 16 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 12 | preeceville
# Processing Record 18 of Set 12 | carbondale
# Processing Record 19 of Set 12 | rajpipla
# Processing Record 20 of Set 12 | teykovo
# Processing Record 21 of Set 12 | rorvik
# Processing Record 22 of Set 12 | rio cuarto
# Processing Record 23 of Set 12 | hualmay
# Processing Record 24 of Set 12 | pinega
# Processing Record 25 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | krasnoselkup
# Processing Record 27 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 12 | kirakira
# Processing Record 29 of Set 12 | salym
# Processing Record 30 of Set 12 | amga
# Processing Record 31 of Set 12 | kemijarvi
# Processing Record 32 of Set 12 | kelo
# Processing Record 33 of Set 12 | qianan
# Processing Record 34 of Set 12 | high river
# Processing Record 35 of Set 12 | los llanos de aridane
# Processing Record 36 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 37 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 12 | bardsir
# Processing Record 39 of Set 12 | andenes
# Processing Record 40 of Set 12 | lamu
# Processing Record 41 of Set 12 | veriora
# Processing Record 42 of Set 12 | puerto madryn
# Processing Record 43 of Set 12 | okha
# Processing Record 44 of Set 12 | mexticacan
# Processing Record 45 of Set 12 | lake city
# Processing Record 46 of Set 12 | muncar
# Processing Record 47 of Set 12 | glendive
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | burica
# City not found. Skipping...
# Processing Record 50 of Set 12 | roxana
# Processing Record 1 of Set 13 | lugovoy
# Processing Record 2 of Set 13 | sibolga
# Processing Record 3 of Set 13 | harsin
# Processing Record 4 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 13 | yatou
# Processing Record 7 of Set 13 | lebyazhye
# Processing Record 8 of Set 13 | verkh-chebula
# Processing Record 9 of Set 13 | resistencia
# Processing Record 10 of Set 13 | gogrial
# Processing Record 11 of Set 13 | lixourion
# Processing Record 12 of Set 13 | alugan
# Processing Record 13 of Set 13 | hobyo
# Processing Record 14 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 15 of Set 13 | mogadishu
# Processing Record 16 of Set 13 | todos santos
# Processing Record 17 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 13 | tesistan
# Processing Record 19 of Set 13 | san juan
# Processing Record 20 of Set 13 | north bend
# Processing Record 21 of Set 13 | orlik
# Processing Record 22 of Set 13 | malanje
# Processing Record 23 of Set 13 | nchelenge
# Processing Record 24 of Set 13 | tebingtinggi
# Processing Record 25 of Set 13 | cervo
# Processing Record 26 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 13 | aviles
# Processing Record 28 of Set 13 | denpasar
# Processing Record 29 of Set 13 | baykit
# Processing Record 30 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 13 | cravo norte
# Processing Record 32 of Set 13 | vila velha
# Processing Record 33 of Set 13 | holguin
# Processing Record 34 of Set 13 | kamenka
# Processing Record 35 of Set 13 | sabang
# Processing Record 36 of Set 13 | weatherford
# Processing Record 37 of Set 13 | khorixas
# Processing Record 38 of Set 13 | nouakchott
# Processing Record 39 of Set 13 | chengde
# Processing Record 40 of Set 13 | kutum
# Processing Record 41 of Set 13 | novo aripuana
# Processing Record 42 of Set 13 | charters towers
# Processing Record 43 of Set 13 | mapastepec
# Processing Record 44 of Set 13 | griffith
# Processing Record 45 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 46 of Set 13 | buarcos
# Processing Record 47 of Set 13 | zvishavane
# Processing Record 48 of Set 13 | aklavik
# Processing Record 49 of Set 13 | clifton
# Processing Record 50 of Set 13 | keelung
# Processing Record 1 of Set 14 | conde
# Processing Record 2 of Set 14 | ilhabela
# Processing Record 3 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 14 | mezen
# Processing Record 5 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 6 of Set 14 | manuk mangkaw
# Processing Record 7 of Set 14 | porbandar
# Processing Record 8 of Set 14 | kruisfontein
# Processing Record 9 of Set 14 | camocim
# Processing Record 10 of Set 14 | riberalta
# Processing Record 11 of Set 14 | sulangan
# Processing Record 12 of Set 14 | herat
# Processing Record 13 of Set 14 | coquimbo
# Processing Record 14 of Set 14 | agadir
# Processing Record 15 of Set 14 | le port
# Processing Record 16 of Set 14 | luwuk
# Processing Record 17 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 18 of Set 14 | pravda
# Processing Record 19 of Set 14 | prince rupert
# Processing Record 20 of Set 14 | seminole
# Processing Record 21 of Set 14 | russell
# Processing Record 22 of Set 14 | vanavara
# Processing Record 23 of Set 14 | moussoro
# Processing Record 24 of Set 14 | kempele
# Processing Record 25 of Set 14 | arman
# Processing Record 26 of Set 14 | bandarbeyla
# Processing Record 27 of Set 14 | half moon bay
# Processing Record 28 of Set 14 | romanovka
# Processing Record 29 of Set 14 | fort nelson
# Processing Record 30 of Set 14 | bure
# Processing Record 31 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 14 | jangipur
# Processing Record 33 of Set 14 | kurumkan
# Processing Record 34 of Set 14 | wajir
# Processing Record 35 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 14 | te anau
# Processing Record 38 of Set 14 | gedo
# Processing Record 39 of Set 14 | thai binh
# Processing Record 40 of Set 14 | abha
# Processing Record 41 of Set 14 | qui nhon
# Processing Record 42 of Set 14 | cabungan
# Processing Record 43 of Set 14 | oneida
# Processing Record 44 of Set 14 | tiruchchendur
# Processing Record 45 of Set 14 | mandali
# Processing Record 46 of Set 14 | unye
# City not found. Skipping...
# Processing Record 47 of Set 14 | goiatuba
# Processing Record 48 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 14 | paamiut
# Processing Record 50 of Set 14 | hurghada
# Processing Record 1 of Set 15 | anloga
# Processing Record 2 of Set 15 | buala
# Processing Record 3 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 15 | iranshahr
# Processing Record 5 of Set 15 | paita
# Processing Record 6 of Set 15 | pyapon
# Processing Record 7 of Set 15 | shakiso
# Processing Record 8 of Set 15 | horki
# Processing Record 9 of Set 15 | pak kret
# Processing Record 10 of Set 15 | husavik
# Processing Record 11 of Set 15 | havoysund
# Processing Record 12 of Set 15 | darhan
# Processing Record 13 of Set 15 | bagamoyo
# Processing Record 14 of Set 15 | labuhan
# Processing Record 15 of Set 15 | xingyi
# Processing Record 16 of Set 15 | sobolevo
# Processing Record 17 of Set 15 | luganville
# Processing Record 18 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 15 | mattru
# Processing Record 20 of Set 15 | aswan
# Processing Record 21 of Set 15 | kitakata
# Processing Record 22 of Set 15 | zeya
# Processing Record 23 of Set 15 | menongue
# Processing Record 24 of Set 15 | aranda de duero
# Processing Record 25 of Set 15 | lithgow
# Processing Record 26 of Set 15 | mabaruma
# Processing Record 27 of Set 15 | poso
# Processing Record 28 of Set 15 | melendugno
# Processing Record 29 of Set 15 | key west
# Processing Record 30 of Set 15 | zhanaozen
# Processing Record 31 of Set 15 | kifri
# Processing Record 32 of Set 15 | channel-port aux basques
# Processing Record 33 of Set 15 | ambon
# Processing Record 34 of Set 15 | marawi
# Processing Record 35 of Set 15 | dehloran
# Processing Record 36 of Set 15 | leh
# Processing Record 37 of Set 15 | medea
# Processing Record 38 of Set 15 | fuling
# Processing Record 39 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 40 of Set 15 | abu samrah
# Processing Record 41 of Set 15 | vasilyevskiy mokh
# Processing Record 42 of Set 15 | vryburg
# Processing Record 43 of Set 15 | mirnyy
# Processing Record 44 of Set 15 | newport
# Processing Record 45 of Set 15 | tafalla
# Processing Record 46 of Set 15 | tura
# Processing Record 47 of Set 15 | lamar
# Processing Record 48 of Set 15 | tilichiki
# Processing Record 49 of Set 15 | sooke
# Processing Record 50 of Set 15 | riyadh
# Processing Record 1 of Set 16 | salamiyah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
print(city_weather)
# Out:
# {'coord': {'lon': 37.0532, 'lat': 35.0113}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 71.82, 'feels_like': 71.8, 'temp_min': 71.82, 'temp_max': 71.82, 'pressure': 1014, 'humidity': 66, 'sea_level': 1014, 'grnd_level': 962}, 'visibility': 10000, 'wind': {'speed': 6.78, 'deg': 249, 'gust': 8.05}, 'clouds': {'all': 0}, 'dt': 1664482090, 'sys': {'country': 'SY', 'sunrise': 1664421880, 'sunset': 1664464777}, 'timezone': 10800, 'id': 164947, 'name': 'Salamiyah', 'cod': 200}

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Fortuna  40.5982 -124.1573     71.35        72           0
# 1  Longyearbyen  78.2186   15.6401     40.84        93          75
# 2        Castro -24.7911  -50.0119     53.24        93         100
# 3    Morant Bay  17.8815  -76.4093     86.70        76         100
# 4    Chokurdakh  70.6333  147.9167     22.12        90          91
# 5         Muros  42.7762   -9.0603     59.09        89           5
# 6          Faya  18.3851   42.4509     66.31        24           4
# 7  North Platte  41.1239 -100.7654     81.12        34           0
# 8       Huarmey -10.0681  -78.1522     67.30        70          13
# 9     Jamestown  42.0970  -79.2353     59.02        50          75
#
#    Wind Speed Country Weather Description
# 0        8.01      US           clear sky
# 1        2.30      SJ       broken clouds
# 2        7.78      BR     overcast clouds
# 3        3.33      JM     overcast clouds
# 4        4.07      RU     overcast clouds
# 5        8.43      ES           clear sky
# 6        5.35      SA           clear sky
# 7       14.97      US           clear sky
# 8       11.45      PE          few clouds
# 9        8.05      US       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Rename Weather Description to Current Description
city_data_df.rename(columns = {"Weather Description":"Current Description"}, inplace = True)

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Fortuna      US  40.5982 -124.1573     71.35        72           0
# 1  Longyearbyen      SJ  78.2186   15.6401     40.84        93          75
# 2        Castro      BR -24.7911  -50.0119     53.24        93         100
# 3    Morant Bay      JM  17.8815  -76.4093     86.70        76         100
# 4    Chokurdakh      RU  70.6333  147.9167     22.12        90          91
# 5         Muros      ES  42.7762   -9.0603     59.09        89           5
# 6          Faya      SA  18.3851   42.4509     66.31        24           4
# 7  North Platte      US  41.1239 -100.7654     81.12        34           0
# 8       Huarmey      PE -10.0681  -78.1522     67.30        70          13
# 9     Jamestown      US  42.0970  -79.2353     59.02        50          75
#
#    Wind Speed Current Description
# 0        8.01           clear sky
# 1        2.30       broken clouds
# 2        7.78     overcast clouds
# 3        3.33     overcast clouds
# 4        4.07     overcast clouds
# 5        8.43           clear sky
# 6        5.35           clear sky
# 7       14.97           clear sky
# 8       11.45          few clouds
# 9        8.05       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
